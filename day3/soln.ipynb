# %%
from aocd import data
d=[]
for line in data.splitlines():
    d.append(line)
print(d)
# Out:
# ['.#..........#......#..#.....#..', '....#.............#.#....#..#..', '.....##...###....#..#.......#..', '.#....#..#......#........#.....', '.#.........###.#..........##...', '...............##........#.....', '#..#..........#..##..#....#.#..', '....#.##....#..#...#.#....#....', '...###...#............#.#......', '#.........#..#...............#.', '#.#...........#...............#', '..#.#......#..###.#...#..##....', '.....#..#..#..#............#...', '......#.......#.....#....##....', '#......#...#.......#.#.#.......', '...........##.#.............#..', '.#.........#..#.####...........', '..#...........#....##..........', '#...........#.......#..#.#.....', '.....##...#.....#..##..#..#....', '#.#..........................#.', '##.....#..........#.......##..#', '....#..#............#.#.#......', '.......#.......#..#............', '...#.#..........#..#.....#.....', '.....#...##..##.....##........#', '.#.....#........##............#', '..#....#.#...#.....#.##........', '........##.....#
# ...

# %%
count=0 
i=1
j=3
while i<len(d):
    line = d[i]
    if line[j%len(line)]=='#':
        count+=1
    i+=1
    j+=3
print(count)
# Out:
# 247

# %%
count2=0 
i=1
j=1
while i<len(d):
    line = d[i]
    if line[j%len(line)]=='#':
        count2+=1
    i+=1
    j+=1
print(count2)
# Out:
# 78

# %%
count3=0 
i=1
j=5
while i<len(d):
    line = d[i]
    if line[j%len(line)]=='#':
        count3+=1
    i+=1
    j+=5
print(count3)
# Out:
# 68

# %%
count4=0 
i=1
j=7
flag=True
while i<len(d):
    line = d[i]
    if line[j%len(line)]=='#':
        count4+=1
    i+=1
    j+=7
print(count4)
# Out:
# 69

# %%
count5=0 
i=2
j=1
flag=True
while i<len(d):
    line = d[i]
    if line[j%len(line)]=='#':
        count5+=1
    i+=2
    j+=1
print(count5)
# Out:
# 33

# %%
print(count*count2*count3*count4*count5)
# Out:
# 2983070376
